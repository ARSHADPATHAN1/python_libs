# %%
import numpy as np
import pandas as pd

# %%
dict1 = {
    "name" :['harry', 'rohan', 'skillf' ,'shub'],
    "marks":[92, 34, 24, 17],
    "city":['rampur', 'kolkata', 'bareilly', 'kasrawad']
}

# %%
df = pd.DataFrame(dict1)

# %%
df
# Out:
#      name  marks      city
# 0   harry     92    rampur
# 1   rohan     34   kolkata
# 2  skillf     24  bareilly
# 3    shub     17  kasrawad

# %% [markdown]
# # if we want an excel sheet which contain above info

# %%
df.to_csv('friends.csv')

# %% [markdown]
# # if we donot want index to be saved in csv file then give index='false'

# %%
df.to_csv('friends_indFalse.csv', index=False)

# %% [markdown]
# # if we want to sea start some rows use head(no.of rows)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2)
# Out:
#      name  marks      city
# 2  skillf     24  bareilly
# 3    shub     17  kasrawad

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      name  marks      city
# 0   harry     92    rampur
# 1   rohan     34   kolkata
# 2  skillf     24  bareilly
# 3    shub     17  kasrawad>

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %% [markdown]
# # how to read file csv

# %%
z = pd.read_csv('arshad.csv')

# %%
z
# Out:
#    Unnamed: 0    name  marks      city      place
# 0           0   harry     92    rampur  karnataka
# 1           1   rohan     34   kolkata      delhi
# 2           2  skillf     24  bareilly     kanpur
# 3           3    shub     17  kasrawad   dhlokpur

# %%
z.describe()
# Out:
#        Unnamed: 0     marks
# count    4.000000   4.00000
# mean     1.500000  41.75000
# std      1.290994  34.21866
# min      0.000000  17.00000
# 25%      0.750000  22.25000
# 50%      1.500000  29.00000
# 75%      2.250000  48.50000
# max      3.000000  92.00000

# %%
z['city']
# Out:
# 0      rampur
# 1     kolkata
# 2    bareilly
# 3    kasrawad
# Name: city, dtype: object

# %%
z['city'][0]
# Out:
# 'rampur'

# %%
z.index = ['first','second','third','fourth']

# %%
z
# Out:
#         Unnamed: 0    name  marks      city      place
# first            0   harry     92    rampur  karnataka
# second           1   rohan     34   kolkata      delhi
# third            2  skillf     24  bareilly     kanpur
# fourth           3    shub     17  kasrawad   dhlokpur

# %% [markdown]
# # pandas is an open source data analysis library written in python
#
# it provides rich and highly robust data operation

# %% [markdown]
# **Pandas the 2 types of data structure
#     a) series--1D array
#     b) Dataframe-- tabular spreadsheet like structure

# %%
ser =pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.659948
# 1     0.257416
# 2     0.839821
# 3     0.795284
# 4     0.018219
# 5     0.255862
# 6     0.809243
# 7     0.775737
# 8     0.602007
# 9     0.569659
# 10    0.242806
# 11    0.154368
# 12    0.950697
# 13    0.515644
# 14    0.788616
# 15    0.377165
# 16    0.493464
# 17    0.436935
# 18    0.728692
# 19    0.456798
# 20    0.369801
# 21    0.301072
# 22    0.495114
# 23    0.966958
# 24    0.142774
# 25    0.107962
# 26    0.822321
# 27    0.868726
# 28    0.779655
# 29    0.228320
# 30    0.197103
# 31    0.210602
# 32    0.372436
# 33    0.498191
# dtype: float64

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
newdf= pd.DataFrame(np.random.rand(334,5) , index=np.arange(334))

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.981387  0.047178  0.410469  0.906853  0.569243
# 1  0.016836  0.734050  0.126945  0.263769  0.488318
# 2  0.387189  0.012013  0.944811  0.358023  0.603031
# 3  0.111808  0.556741  0.320828  0.609528  0.088663
# 4  0.626778  0.604772  0.422851  0.016174  0.726360

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
newdf.describe()
# Out:
#                 0           1           2           3           4
# count  334.000000  334.000000  334.000000  334.000000  334.000000
# mean     0
#
# [334 rows x 5 columns]

# %%
newdf.sort_index(axis=1)
# Out:
#             0         1         2         3         4
# 0    0.981387  0.047178  0.410469  0.906853  0.569243
# 1    0.016836  0.734050  0.126945  0.263769  0.488318
# 2    0.387189  0.012013  0.944811  0.358023  0.603031
# 3    0.111808  0.556741  0.320828  0.609528  0.088663
# 4    0.626778  0.604772  0.422851  0.016174  0.726360
# ..        ...       ...       ...       ...       ...
# 329  0.511623  0.155061  0.402782  0.758123  0.063201
# 330  0.021982  0.909521  0.208313  0.609759  0.189407
# 331  0.808198  0.953497  0.759404  0.541220  0.445339
# 332  0.458430  0.566239  0.793475  0.000526  0.958334
# 333  0.860946  0.212859  0.623614  0.940914  0.617477
#
# [334 rows x 5 columns]

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0.981387  0.047178  0.410469  0.906853  0.569243
# 1  0.016836  0.734050  0.126945  0.263769  0.488318
# 2  0.387189  0.012013  0.944811  0.358023  0.603031
# 3  0.111808  0.556741  0.320828  0.609528  0.088663
# 4  0.626778  0.604772  0.422851  0.016174  0.726360

# %%
newdf[0]
# Out:
# 0      0.981387
# 1      0.016836
# 2      0.387189
# 3      0.111808
# 4      0.626778
#          ...
# 329    0.511623
# 330    0.021982
# 331    0.808198
# 332    0.458430
# 333    0.860946
# Name: 0, Length: 334, dtype: float64

# %%
type(newdf)
# Out:
# pandas.core.frame.DataFrame

# %%
type(newdf[0])
# Out:
# pandas.core.series.Series

# %% [markdown]
# newdf2 = newdf i.e we have created a view of newdf if we change in newdf2 then it will change in newdf also

# %% [markdown]
# **To create copy
# we use newdf2 = newdf.copy()

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.981387  0.047178  0.410469  0.906853  0.569243
# 1    0.016836  0.734050  0.126945  0.263769  0.488318
# 2    0.387189  0.012013  0.944811  0.358023  0.603031
# 3    0.111808  0.556741  0.320828  0.609528  0.088663
# 4    0.626778  0.604772  0.422851  0.016174  0.726360
# ..        ...       ...       ...       ...       ...
# 329  0.511623  0.155061  0.402782  0.758123  0.063201
# 330  0.021982  0.909521  0.208313  0.609759  0.189407
# 331  0.808198  0.953497  0.759404  0.541220  0.445339
# 332  0.458430  0.566239  0.793475  0.000526  0.958334
# 333  0.860946  0.212859  0.623614  0.940914  0.617477
#
# [334 rows x 5 columns]

# %%
newdf.drop(0, axis=1)
# Out:
#             1         2         3         4
# 0    0.047178  0.410469  0.906853  0.569243
# 1    0.734050  0.126945  0.263769  0.488318
# 2    0.012013  0.944811  0.358023  0.603031
# 3    0.556741  0.320828  0.609528  0.088663
# 4    0.604772  0.422851  0.016174  0.726360
# ..        ...       ...       ...       ...
# 329  0.155061  0.402782  0.758123  0.063201
# 330  0.909521  0.208313  0.609759  0.189407
# 331  0.953497  0.759404  0.541220  0.445339
# 332  0.566239  0.793475  0.000526  0.958334
# 333  0.212859  0.623614  0.940914  0.617477
#
# [334 rows x 4 columns]

# %%
newdf.loc[[1,2],[3,4]]
# Out:
#           3         4
# 1  0.263769  0.488318
# 2  0.358023  0.603031

# %%
newdf.loc[[1,2], :]
# Out:
#           0         1         2         3         4
# 1  0.016836  0.734050  0.126945  0.263769  0.488318
# 2  0.387189  0.012013  0.944811  0.358023  0.603031

# %%
newdf.loc[(newdf[2]<0.3)]
# Out:
#             0         1         2         3         4
# 1    0.016836  0.734050  0.126945  0.263769  0.488318
# 6    0.092981  0.813800  0.085199  0.986276  0.675064
# 8    0.541221  0.328432  0.274705  0.425801  0.262430
# 10   0.730977  0.908674  0.209980  0.762736  0.924916
# 11   0.573006  0.792138  0.180557  0.869337  0.630173
# ..        ...       ...       ...       ...       ...
# 314  0.251282  0.479647  0.253538  0.473303  0.695182
# 315  0.638531  0.348324  0.225180  0.214779  0.437052
# 317  0.613529  0.678587  0.225373  0.313584  0.001896
# 324  0.958799  0.668989  0.231979  0.564567  0.927983
# 330  0.021982  0.909521  0.208313  0.609759  0.189407
#
# [98 rows x 5 columns]

# %%
newdf.loc[ (newdf[2]<0.3) & (newdf[3]>0.1)]
# Out:
#             0         1         2         3         4
# 1    0.016836  0.734050  0.126945  0.263769  0.488318
# 6    0.092981  0.813800  0.085199  0.986276  0.675064
# 8    0.541221  0.328432  0.274705  0.425801  0.262430
# 10   0.730977  0.908674  0.209980  0.762736  0.924916
# 11   0.573006  0.792138  0.180557  0.869337  0.630173
# ..        ...       ...       ...       ...       ...
# 314  0.251282  0.479647  0.253538  0.473303  0.695182
# 315  0.638531  0.348324  0.225180  0.214779  0.437052
# 317  0.613529  0.678587  0.225373  0.313584  0.001896
# 324  0.958799  0.668989  0.231979  0.564567  0.927983
# 330  0.021982  0.909521  0.208313  0.609759  0.189407
#
# [91 rows x 5 columns]

# %%
newdf.iloc[0,4]
# Out:
# 0.5692434077437327

# %%
newdf.head(2)
# Out:
#           0         1         2         3         4
# 0  0.981387  0.047178  0.410469  0.906853  0.569243
# 1  0.016836  0.734050  0.126945  0.263769  0.488318

# %% [markdown]
# # delete any row

# %%
newdf.drop([0] ,axis=1)
# Out:
#             1         2         3         4
# 0    0.047178  0.410469  0.906853  0.569243
# 1    0.734050  0.126945  0.263769  0.488318
# 2    0.012013  0.944811  0.358023  0.603031
# 3    0.556741  0.320828  0.609528  0.088663
# 4    0.604772  0.422851  0.016174  0.726360
# ..        ...       ...       ...       ...
# 329  0.155061  0.402782  0.758123  0.063201
# 330  0.909521  0.208313  0.609759  0.189407
# 331  0.953497  0.759404  0.541220  0.445339
# 332  0.566239  0.793475  0.000526  0.958334
# 333  0.212859  0.623614  0.940914  0.617477
#
# [334 rows x 4 columns]

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.981387  0.047178  0.410469  0.906853  0.569243
# 1    0.016836  0.734050  0.126945  0.263769  0.488318
# 2    0.387189  0.012013  0.944811  0.358023  0.603031
# 3    0.111808  0.556741  0.320828  0.609528  0.088663
# 4    0.626778  0.604772  0.422851  0.016174  0.726360
# ..        ...       ...       ...       ...       ...
# 329  0.511623  0.155061  0.402782  0.758123  0.063201
# 330  0.021982  0.909521  0.208313  0.609759  0.189407
# 331  0.808198  0.953497  0.759404  0.541220  0.445339
# 332  0.458430  0.566239  0.793475  0.000526  0.958334
# 333  0.860946  0.212859  0.623614  0.940914  0.617477
#
# [334 rows x 5 columns]

# %%
newdf.reset_index()
# Out:
#      index         0         1         2         3         4
# 0        0  0.981387  0.047178  0.410469  0.906853  0.569243
# 1        1  0.016836  0.734050  0.126945  0.263769  0.488318
# 2        2  0.387189  0.012013  0.944811  0.358023  0.603031
# 3        3  0.111808  0.556741  0.320828  0.609528  0.088663
# 4        4  0.626778  0.604772  0.422851  0.016174  0.726360
# ..     ...       ...       ...       ...       ...       ...
# 329    329  0.511623  0.155061  0.402782  0.758123  0.063201
# 330    330  0.021982  0.909521  0.208313  0.609759  0.189407
# 331    331  0.808198  0.953497  0.759404  0.541220  0.445339
# 332    332  0.458430  0.566239  0.793475  0.000526  0.958334
# 333    333  0.860946  0.212859  0.623614  0.940914  0.617477
#
# [334 rows x 6 columns]

# %%
newdf.reset_index(drop=True)
# Out:
#             0         1         2         3         4
# 0    0.981387  0.047178  0.410469  0.906853  0.569243
# 1    0.016836  0.734050  0.126945  0.263769  0.488318
# 2    0.387189  0.012013  0.944811  0.358023  0.603031
# 3    0.111808  0.556741  0.320828  0.609528  0.088663
# 4    0.626778  0.604772  0.422851  0.016174  0.726360
# ..        ...       ...       ...       ...       ...
# 329  0.511623  0.155061  0.402782  0.758123  0.063201
# 330  0.021982  0.909521  0.208313  0.609759  0.189407
# 331  0.808198  0.953497  0.759404  0.541220  0.445339
# 332  0.458430  0.566239  0.793475  0.000526  0.958334
# 333  0.860946  0.212859  0.623614  0.940914  0.617477
#
# [334 rows x 5 columns]

# %%
newdf[3].isnull()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 329    False
# 330    False
# 331    False
# 332    False
# 333    False
# Name: 3, Length: 334, dtype: bool

# %%
newdf[2]=None

# %%
newdf
# Out:
#             0         1     2         3         4
# 0    0.981387  0.047178  None  0.906853  0.569243
# 1    0.016836  0.734050  None  0.263769  0.488318
# 2    0.387189  0.012013  None  0.358023  0.603031
# 3    0.111808  0.556741  None  0.609528  0.088663
# 4    0.626778  0.604772  None  0.016174  0.726360
# ..        ...       ...   ...       ...       ...
# 329  0.511623  0.155061  None  0.758123  0.063201
# 330  0.021982  0.909521  None  0.609759  0.189407
# 331  0.808198  0.953497  None  0.541220  0.445339
# 332  0.458430  0.566239  None  0.000526  0.958334
# 333  0.860946  0.212859  None  0.940914  0.617477
#
# [334 rows x 5 columns]

# %%
newdf[2].isnull()
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 329    True
# 330    True
# 331    True
# 332    True
# 333    True
# Name: 2, Length: 334, dtype: bool

# %%
newdf.loc[:, [2]]=56

# %%
newdf
# Out:
#             0         1   2         3         4
# 0    0.981387  0.047178  56  0.906853  0.569243
# 1    0.016836  0.734050  56  0.263769  0.488318
# 2    0.387189  0.012013  56  0.358023  0.603031
# 3    0.111808  0.556741  56  0.609528  0.088663
# 4    0.626778  0.604772  56  0.016174  0.726360
# ..        ...       ...  ..       ...       ...
# 329  0.511623  0.155061  56  0.758123  0.063201
# 330  0.021982  0.909521  56  0.609759  0.189407
# 331  0.808198  0.953497  56  0.541220  0.445339
# 332  0.458430  0.566239  56  0.000526  0.958334
# 333  0.860946  0.212859  56  0.940914  0.617477
#
# [334 rows x 5 columns]

# %% [markdown]
# # for inspect we can use
# 1)df.head
# 2)df.tail
# 3)df.shape
# 4)df.describe()
# 5)df.info()
# 6)df['name'].value_count()
# 7)df.notnull()
# 8)df.isnull()
